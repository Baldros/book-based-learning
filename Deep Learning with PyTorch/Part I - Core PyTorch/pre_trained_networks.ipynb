# %% [markdown]
# # Apresentação

# %%
from torchvision import models

# %%
for model in dir(models):
    if not model.startswith("_"):
        print(model)

# %%
# Example of instantiating a pre-trained model
alexnet = models.AlexNet()
